# %%
import os
import torch
from torchvision import models, transforms
from PIL import Image
images_folder='PetImages/Dog'

images=os.listdir(images_folder)

weights = models.ResNet18_Weights.IMAGENET1K_V1
model = models.resnet18(weights=weights)

model.eval()


transform=transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    
])

for i in range(len(images)):
    image_path = os.path.join(images_folder, images[i])
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)

    with torch.no_grad():
        output = model(image)
    
    _, predicted = torch.max(output, 1)
    print(f"{images[i]} predicted as class {weights.meta["categories"][predicted]}")
    

#Annoy is not working with this model
# Out:
# 0.jpg predicted as class Scottish deerhound
# 1.jpg predicted as class Chesapeake Bay retriever
# 10.jpg predicted as class Walker hound
# 100.jpg predicted as class Labrador retriever
# 1000.jpg predicted as class Siberian husky
# 10000.jpg predicted as class kelpie
# 10001.jpg predicted as class Irish wolfhound
# 10002.jpg predicted as class toy terrier
# 10003.jpg predicted as class golden retriever
# 10004.jpg predicted as class German short-haired pointer
# 10005.jpg predicted as class West Highland white terrier
# 10006.jpg predicted as class Labrador retriever
# 10007.jpg predicted as class paper towel
# 10008.jpg predicted as class maillot tank suit
# 10009.jpg predicted as class soft-coated wheaten terrier
# 1001.jpg predicted as class whippet
# 10010.jpg predicted as class Weimaraner
# 10011.jpg predicted as class redbone
# 10012.jpg predicted as class Angora
# 10013.jpg predicted as class German shepherd
# 10014.jpg predicted as class German shepherd
# 10015.jpg predicted as class vizsla
# 10016.jpg predicted as class malamute
# 10017.jpg predicted as class mosquito net
# 10018.jpg predicted as class shower curtain
# 10019.jpg predicted as class chainlink fence
# 1002.jpg predicted as class Labrador retriever
# 10020.jpg predicted as class groenendael
# 10021.jpg predicted as class Siberian husky
# 10022.jpg predicted as class boxer
# 10023.jpg predicted as class tub
# 10024.jpg predicted as class bassinet
# 10025.jpg predicted as class toy terrier
# 10026.jpg predicted as class African elephant
# 10027.jpg predicted as class American Staffordshire terrier
# 10028.jpg predicted as class whippet
# 10029.jpg predicted as class miniature poodle
# 1003.jpg predicted as class American Staffordshire terrier
# 10030.jpg predicted as class Great Dane
# 10031.jpg predicted as class Saluki
# 10032.jpg predicted as class Gordon setter
# 10033.jpg predicted as class jellyfish
# 10034.jpg predicted as class Pembroke
# 10035.jpg predicted as class bloodhound
# 10036.jpg predicted as class American Staffordshire terrier
# 10037.jpg predicted as class beagle
# 10038.jpg predicted as class flat-coated retriever
# 10039.jpg predicted as class Brittany spaniel
# 1004.jpg predicted as class Labrador retriever
# 10040.jpg predicted as class Chihuahua
# 10041.jpg predicted as class German shepherd
# 10042.jpg predicted as class toy terrier
# 10043.jpg predicted as class giant schnauzer
# 10044.jpg predicted as class Labrador retriever
# 10045.jpg predicted as class Eskimo dog
# 10046.jpg predicted as class radio telescope
# 10047.jpg predicted as class Japanese spaniel
# 10048.jpg predicted as class toy terrier
# 10049.jpg predicted as class mosquito net
# 1005.jpg predicted as class vizsla
# 10050.jpg predicted as class Border collie
# 10051.jpg predicted as class Ibizan hound
# 10052.jpg predicted as class Eskimo dog
# 10053.jpg predicted as class chainlink fence
# 10054.jpg predicted as class Siberian husky
# 10055.jpg predicted as class Maltese dog
# 10056.jpg predicted as class American Staffordshire terrier
# 10057.jpg predicted as class Tibetan mastiff
# 10058.jpg predicted as class toilet tissue
# 10059.jpg predicted as class tub
# 1006.jpg predicted as class Labrador retriever
# 10060.jpg predicted as class Weimaraner
# 10061.jpg predicted as class Doberman
# 10062.jpg predicted as class Chihuahua
# 10063.jpg predicted as class Chesapeake Bay retriever
# 10064.jpg predicted as class clumber
# 10065.jpg predicted as class Great Dane
# 10066.jpg predicted as class Labrador retriever
# 10067.jpg predicted as class Labrador retriever
# 10068.jpg predicted as class Eskimo dog
# 10069.jpg predicted as class borzoi
# 1007.jpg predicted as class sloth bear
# 10070.jpg predicted as class Weimaraner
# 10071.jpg predicted as class Great Dane
# 10072.jpg predicted as class mosquito net
# 10073.jpg predicted as class whippet
# 10074.jpg predicted as class Labrador retriever
# 10075.jpg predicted as class Chesapeake Bay retriever
# 10076.jpg predicted as class shower curtain
# 10077.jpg predicted as class stingray
# 10078.jpg predicted as class flat-coated retriever
# 10079.jpg predicted as class clumber
# 1008.jpg predicted as class Labrador retriever
# 10080.jpg predicted as class schipperke
# 10081.jpg predicted as class redbone
# 10082.jpg predicted as class Saint Bernard
# 10083.jpg predicted as class whippet
# 10084.jpg predicted as class Great Pyrenees
# 10085.jpg predicted as class Irish wolfhound
# 10086.jpg predicted as class American Staffordshire terrier
# 10087.jpg predicted as class Weimaraner
# 10088.jpg predicted as class Bouvier des Flandres
# 10089.jpg predicted as class cairn
# 1009.jpg predicted as class Chihuahua
# 10090.jpg predicted as class golden retriever
# 10091.jpg predicted as class toilet tissue
# 10092.jpg predicted as class whippet
# 10093.jpg predicted as class Pomeranian
# 10094.jpg predicted as class mosquito net
# 10095.jpg predicted as class Chihuahua
# 10096.jpg predicted as class Labrador retriever
# 10097.jpg predicted as class American Staffordshire terrier
# 10098.jpg predicted as class Chesapeake Bay retriever
# 10099.jpg predicted as class malinois
# 101.jpg predicted as class Weimaraner
# 1010.jpg predicted as class kuvasz
# 10100.jpg predicted as class black-and-tan coonhound
# 10101.jpg predicted as class muzzle
# 10102.jpg predicted as class Ibizan hound
# 10103.jpg predicted as class syringe
# 10104.jpg predicted as class mosquito net
# 10105.jpg predicted as class Pekinese
# 10106.jpg predicted as class whippet
# 10107.jpg predicted as class Weimaraner
# 10108.jpg predicted as class Great Pyrenees
# 10109.jpg predicted as class Sealyham terrier
# 1011.jpg predicted as class Afghan hound
# 10110.jpg predicted as class Saluki
# 10111.jpg predicted as class Labrador retriever
# 10112.jpg predicted as class Labrador retriever
# 10113.jpg predicted as class dingo
# 10114.jpg predicted as class Irish wolfhound
# 10115.jpg predicted as class Labrador retriever
# 10116.jpg predicted as class Labrador retriever
# 10117.jpg predicted as class Chesapeake Bay retriever
# 10118.jpg predicted as class golden retriever
# 10119.jpg predicted as class Labrador retriever
# 1012.jpg predicted as class English foxhound
# 10120.jpg predicted as class golden retriever
# 10121.jpg predicted as class Walker hound
# 10122.jpg predicted as class toy terrier
# 10123.jpg predicted as class cassette
# 10124.jpg predicted as class American Staffordshire terrier
# 10125.jpg predicted as class cairn
# 10126.jpg predicted as class Weimaraner
# 10127.jpg predicted as class cocker spaniel
# 10128.jpg predicted as class basset
# 10129.jpg predicted as class Weimaraner
# 1013.jpg predicted as class German short-haired pointer
# 10130.jpg predicted as class ice bear
# 10131.jpg predicted as class Labrador retriever
# 10132.jpg predicted as class Brittany spaniel
# 10133.jpg predicted as class boxer
# 10134.jpg predicted as class Italian greyhound
# 10135.jpg predicted as class Great Dane
# 10136.jpg predicted as class Walker hound
# 10137.jpg predicted as class Labrador retriever
# 10138.jpg predicted as class Newfoundland
# 10139.jpg predicted as class Labrador retriever
# 1014.jpg predicted as class Maltese dog
# 10140.jpg predicted as class Labrador retriever
# 10141.jpg predicted as class Lhasa
# 10142.jpg predicted as class dugong
# 10143.jpg predicted as class Labrador retriever
# 10144.jpg predicted as class beagle
# 10145.jpg predicted as class Labrador retriever
# 10146.jpg predicted as class Walker hound
# 10147.jpg predicted as class Weimaraner
# 10148.jpg predicted as class Chihuahua
# 10149.jpg predicted as class Weimaraner
# 1015.jpg predicted as class German shepherd
# 10150.jpg predicted as class Norwegian elkhound
# 10151.jpg predicted as class collie
# 10152.jpg predicted as class American Staffordshire terrier
# 10153.jpg predicted as class cowboy hat
# 10154.jpg predicted as class Maltese dog
# 10155.jpg predicted as class bassinet
# 10156.jpg predicted as class Labrador retriever
# 10157.jpg predicted as class shovel
# 10158.jpg predicted as class Labrador retriever
# 10159.jpg predicted as class Rottweiler
# 1016.jpg predicted as class Labrador retriever
# 10160.jpg predicted as class Saluki
# 10161.jpg predicted as class street sign
# 10162.jpg predicted as class white wolf
# 10163.jpg predicted as class dalmatian
# 10164.jpg predicted as class beagle
# 10165.jpg predicted as class hog
# 10166.jpg predicted as class basset
# 10167.jpg predicted as class golden retriever
# 10168.jpg predicted as class nipple
# 10169.jpg predicted as class Shih-Tzu
# 1017.jpg predicted as class beagle
# 10170.jpg predicted as class Chihuahua
# 10171.jpg predicted as class Saluki
# 10172.jpg predicted as class Weimaraner
# 10173.jpg predicted as class chow
# 10174.jpg predicted as class Great Pyrenees
# 10175.jpg predicted as class llama
# 10176.jpg predicted as class Labrador retriever
# 10177.jpg predicted as class Labrador retriever
# 10178.jpg predicted as class Labrador retriever
# 10179.jpg predicted as class ice bear
# 1018.jpg predicted as class Labrador retriever
# 10180.jpg predicted as class German short-haired pointer
# 10181.jpg predicted as class giant schnauzer
# 10182.jpg predicted as class Labrador retriever
# 10183.jpg predicted as class Staffordshire bullterrier
# 10184.jpg predicted as class Doberman
# 10185.jpg predicted as class American Staffordshire terrier
# 10186.jpg predicted as class handkerchief
# 10187.jpg predicted as class mosquito net
# 10188.jpg predicted as class Rottweiler
# 10189.jpg predicted as class boxer
# 1019.jpg predicted as class American Staffordshire terrier
# 10190.jpg predicted as class pick
# 10191.jpg predicted as class Shih-Tzu
# 10192.jpg predicted as class plastic bag
# 10193.jpg predicted as class Sealyham terrier
# 10194.jpg predicted as class Weimaraner
# 10195.jpg predicted as class stingray
# 10196.jpg predicted as class Labrador retriever
# 10197.jpg predicted as class Ibizan hound
# 10198.jpg predicted as class Doberman
# 10199.jpg predicted as class pug
# 102.jpg predicted as class Labrador retriever
# 1020.jpg predicted as class Bouvier des Flandres
# 10200.jpg predicted as class groenendael
# 10201.jpg predicted as class Labrador retriever
# 10202.jpg predicted as class Maltese dog
# 10203.jpg predicted as class Labrador retriever
# 10204.jpg predicted as class American Staffordshire terrier
# 10205.jpg predicted as class kelpie
# 10206.jpg predicted as class Labrador retriever
# 10207.jpg predicted as class Weimaraner
# 10208.jpg predicted as class cradle
# 10209.jpg predicted as class bloodhound
# 1021.jpg predicted as class Weimaraner
# 10210.jpg predicted as class mousetrap
# 10211.jpg predicted as class plow
# 10212.jpg predicted as class golden retriever
# 10213.jpg predicted as class Lhasa
# 10214.jpg predicted as class schipperke
# 10215.jpg predicted as class Rottweiler
# 10216.jpg predicted as class golden retriever
# 10217.jpg predicted as class Newfoundland
# 10218.jpg predicted as class bloodhound
# 10219.jpg predicted as class Weimaraner
# 1022.jpg predicted as class Eskimo dog
# 10220.jpg predicted as class Labrador retriever
# 10221.jpg predicted as class Chesapeake Bay retriever
# 10222.jpg predicted as class bluetick
# 10223.jpg predicted as class toilet tissue
# 10224.jpg predicted as class Weimaraner
# 10225.jpg predicted as class brassiere
# 10226.jpg predicted as class bathtub
# 10227.jpg predicted as class Greater Swiss Mountain dog
# 10228.jpg predicted as class English setter
# 10229.jpg predicted as class Rottweiler
# 1023.jpg predicted as class miniature pinscher
# 10230.jpg predicted as class Chihuahua
# 10231.jpg predicted as class Labrador retriever
# 10232.jpg predicted as class Tibetan mastiff
# 10233.jpg predicted as class kelpie
# 10234.jpg predicted as class Irish wolfhound
# 10235.jpg predicted as class Labrador retriever
# 10236.jpg predicted as class Labrador retriever
# 10237.jpg predicted as class book jacket
# 10238.jpg predicted as class banjo
# 10239.jpg predicted as class tub
# 1024.jpg predicted as class American Staffordshire terrier
# 10240.jpg predicted as class shower curtain
# 10241.jpg predicted as class Walker hound
# 10242.jpg predicted as class golden retriever
# 10243.jpg predicted as class Brittany spaniel
# 10244.jpg predicted as class Great Pyrenees
# 10245.jpg predicted as class hammerhead
# 10246.jpg predicted as class Weimaraner
# 10247.jpg predicted as class American Staffordshire terrier
# 10248.jpg predicted as class standard poodle
# 10249.jpg predicted as class Labrador retriever
# 1025.jpg predicted as class Doberman
# 10250.jpg predicted as class standard poodle
# 10251.jpg predicted as class Arctic fox
# 10252.jpg predicted as class Irish wolfhound
# 10253.jpg predicted as class kuvasz
# 10254.jpg predicted as class Great Dane
# 10255.jpg predicted as class Eskimo dog
# 10256.jpg predicted as class whippet
# 10257.jpg predicted as class miniature pinscher
# 10258.jpg predicted as class Weimaraner
# 10259.jpg predicted as class golden retriever
# 1026.jpg predicted as class English springer
# 10260.jpg predicted as class Labrador retriever
# 10261.jpg predicted as class chow
# 10262.jpg predicted as class American Staffordshire terrier
# 10263.jpg predicted as class Afghan hound
# 10264.jpg predicted as class brassiere
# 10265.jpg predicted as class Weimaraner
# 10266.jpg predicted as class Siberian husky
# 10267.jpg predicted as class Great Dane
# 10268.jpg predicted as class Labrador retriever
# 10269.jpg predicted as class Staffordshire bullterrier
# 1027.jpg predicted as class dingo
# 10270.jpg predicted as class Staffordshire bullterrier
# 10271.jpg predicted as class basset
# 10272.jpg predicted as class miniature pinscher
# 10273.jpg predicted as class whippet
# 10274.jpg predicted as class borzoi
# 10275.jpg predicted as class Great Pyrenees
# 10276.jpg predicted as class American Staffordshire terrier
# 10277.jpg predicted as class Shetland sheepdog
# 10278.jpg predicted as class Yorkshire terrier
# 10279.jpg predicted as class Labrador retriever
# 1028.jpg predicted as class Great Dane
# 10280.jpg predicted as class American Staffordshire terrier
# 10281.jpg predicted as class Eskimo dog
# 10282.jpg predicted as class kuvasz
# 10283.jpg predicted as class Chesapeake Bay retriever
# 10284.jpg predicted as class standard poodle
# 10285.jpg predicted as class toy poodle
# 10286.jpg predicted as class Labrador retriever
# 10287.jpg predicted as class Italian greyhound
# 10288.jpg predicted as class Labrador retriever
# 10289.jpg predicted as class miniature pinscher
# 1029.jpg predicted as class Chesapeake Bay retriever
# 10290.jpg predicted as class American Staffordshire terrier
# 10291.jpg predicted as class German shepherd
# 10292.jpg predicted as class American Staffordshire terrier
# 10293.jpg predicted as class dingo
# 10294.jpg predicted as class Chihuahua
# 10295.jpg predicted as class Maltese dog
# 10296.jpg predicted as class shower curtain
# 10297.jpg predicted as class bassinet
# 10298.jpg predicted as class Saluki
# 10299.jpg predicted as class Saint Bernard
# 103.jpg predicted as class Labrador retriever
# 1030.jpg predicted as class redbone
# 10300.jpg predicted as class dalmatian
# 10301.jpg predicted as class kelpie
# 10302.jpg predicted as class Maltese dog
# 10303.jpg predicted as class Irish wolfhound
# 10304.jpg predicted as class whippet
# 10305.jpg predicted as class ice bear
# 10306.jpg predicted as class pedestal
# 10307.jpg predicted as class bluetick
# 10308.jpg predicted as class Pomeranian
# 10309.jpg predicted as class clumber
# 1031.jpg predicted as class whippet
# 10310.jpg predicted as class English springer
# 10311.jpg predicted as class black-and-tan coonhound
# 10312.jpg predicted as class chow
# 10313.jpg predicted as class Walker hound
# 10314.jpg predicted as class Great Dane
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 27
#      24 image = transform(image).unsqueeze(0)
#      26 with torch.no_grad():
# ---> 27     output = model(image)
#      29 _, predicted = torch.max(output, 1)
#      30 print(f"{images[i]} predicted as class {weights.meta["categories"][predicted]}")
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\resnet.py:273, in ResNet._forward_impl(self, x)
#     270 x = self.relu(x)
#     271 x = self.maxpool(x)
# --> 273 x = self.layer1(x)
#     274 x = self.layer2(x)
#     275 x = self.layer3(x)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\models\resnet.py:96, in BasicBlock.forward(self, x)
#      93 out = self.bn1(out)
#      94 out = self.relu(out)
# ---> 96 out = self.conv2(out)
#      97 out = self.bn2(out)
#      99 if self.downsample is not None:
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\Aarmaan Choudhary\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
