# %% [markdown]
# **NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP.**
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  # this in Jupyter Notebook
# If not using Jupyter then use plt.show() after plotting
# Out:
# UsageError: unrecognized arguments: # this in Jupyter Notebook

# %% [markdown]
# ## Exercise 1
#
# **Follow along with these steps**
# * Create a figure object called fig using plt.figure()
# * Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax.
# * Plot (x,y) on that axes and set the labels and titles to match the plot below:

# %%
plt.figure(figsize=(8, 4))
plt.plot(x, y, 'r')  # 'r' means here red line
plt.title('y = 2x')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercise 2
# **Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
# Creating first and second axes at [left, bottom, width, height]
ax1 = fig.add_axes([0, 0, 1, 1])

ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])
plt.show()

# %% [markdown]
# **Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
x = np.linspace(0, 200, 100)
y = x
fig = plt.figure()


ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(x, y, color='brown')

ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])
ax2.plot(x, y, color='brown')
ax2.set_xlim(0, 100)
ax2.set_ylim(0, 50)

plt.show()

# %% [markdown]
# ## Exercise 3
#
# **Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1])

ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])

plt.show()

# %% [markdown]
# **Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 100, 100)
y = x
z = y ** 2

fig = plt.figure()
ax1 = fig.add_axes([0, 0, 1, 1])
ax1.plot(x, z)
ax1.set_xlabel('x')
ax1.set_ylabel('z')

ax2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])
ax2.plot(x, z)
ax2.set_xlim(20, 22)
ax2.set_ylim(30,50)
ax2.set_title('zoom')

plt.show()

# %% [markdown]
# ## Exercise 4
#
# **Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 100, 100)
y = x
z = y ** 2
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)


plt.tight_layout()
plt.show()

# %% [markdown]
# **Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
x = np.linspace(0, 100, 100)
y = x
z = y ** 2

# Create subplots (1 row, 2 columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
#Plot x vs y on the first axis
ax1.plot(x, y, 'b--', linewidth=2)  # Blue dashed line
ax1.set_title('x vs y')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

#Plot x vs z on the second axis
ax2.plot(x, z, 'r-', linewidth=2)  # Red solid line
ax2.set_title('x vs z')
ax2.set_xlabel('x')
ax2.set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# **See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
x = np.linspace(0, 100, 100)
y = x
z = y ** 2

# Create subplots (1 row, 2 columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
#Plot x vs y on the first axis
ax1.plot(x, y, 'b--', linewidth=2)  # Blue dashed line
ax1.set_title('x vs y')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

#Plot x vs z on the second axis
ax2.plot(x, z, 'r-', linewidth=2)  # Red solid line
ax2.set_title('x vs z')
ax2.set_xlabel('x')
ax2.set_ylabel('z')
# Out:
# Text(0, 0.5, 'z')

# %% [markdown]
# # Great Job!
